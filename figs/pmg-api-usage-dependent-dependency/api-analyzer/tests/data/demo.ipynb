# %%
from typing import TYPE_CHECKING

import mypkg.core as core

if TYPE_CHECKING:
    from numpy.typing import NDArray

    _: NDArray | None = None

core.run()

# %%
# test usage in separate cell
core.run()

# %%
# Check indented code block
def foo():
    core.run()

# %%
# %matplotlib inline
  # %matplotlib inline  # indented
