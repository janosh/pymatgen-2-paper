# %%
# !uv pip install -U requests python-dotenv openai

PR_JSON_FILE = "_prs.json"  # original PR entries
PR_TOPICS_FILE = "_topics.json"  # LLM summaried
MODEL = "gpt-4.1"  # GPT-5 is very slow
# Out:
# Using Python 3.12.11 environment at: /Users/yang/developer/pymatgen-2-paper/.venv
# Resolved 20 packages in 491ms
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)--------------     0 B/791.77 KiB
# ⠙ Preparing packages... (0/1)-------------- 16.00 KiB/791.77 KiB
# ⠙ Preparing packages... (0/1)-------------- 32.00 KiB/791.77 KiB
# ⠙ Preparing packages... (0/1)-------------- 48.00 KiB/791.77 KiB
# ⠙ Preparing packages... (0/1)-------------- 64.00 KiB/791.77 KiB
# ⠙ Preparing packages... (0/1)-------------- 80.00 KiB/791.77 KiB
# ⠙ Preparing packages... (0/1)-------------- 96.00 KiB/791.77 KiB
# ⠙ Preparing packages... (0/1)-------------- 112.00 KiB/791.77 KiB
# ⠙ Preparing packages... (0/1)-------------- 121.44 KiB/791.77 KiB
# ⠙ Preparing packages... (0/1)-------------- 137.44 KiB/791.77 KiB
# ⠙ Preparing packages... (0/1)-------------- 153.44 KiB/791.77 KiB
# ⠙ Preparing packages... (0/1)-------------- 169.44 KiB/791.77 KiB
# ⠙ Preparing packages... (0/1)-------------- 185.44 KiB/791.77 KiB
# ⠙ Preparing packages... (0/1)-------------- 201.44 KiB/791.77 KiB
# ⠙ Preparing packages... (0/1)-------------- 217.44 KiB/791.77 KiB
# ⠙ Preparing packages... (0/1)-------------- 233.44 KiB/791.77 KiB
# ⠙ Preparing packages... (0/1)-------------- 249.44 KiB/791.77 KiB
# ⠙ Preparing packages... (0/1)-------------- 265.44 KiB/791.77 KiB
# ⠙ Preparing packages... (0/1)-------------- 281.44 KiB/791.77 KiB
# ⠹ Preparing packages... (0/1)-------------- 361.44 KiB/791.77 KiB
# Prepared 1 package in 204ms
# Uninstalled 1 package in 64ms
# Installed 1 package in 8ms
#  - openai==1.100.2
#  + openai==1.101.0

# %%
# Get all PRs (title, date)
# Please set `GITHUB_TOKEN` to increate GitHub rate limit

import os
import requests
import json


url = "https://api.github.com/repos/materialsproject/pymatgen/pulls"
params = {"state": "all", "per_page": 100, "page": 1}

# Setup GitHub token (for higher API rate limit)
if not (token := os.environ.get("GITHUB_TOKEN")):
    raise RuntimeError("Please set your GitHub token in GITHUB_TOKEN env var.")
headers = {"Authorization": f"Bearer {token}"}

# Load previous cache if exists
if os.path.exists(PR_JSON_FILE):
    print("Cache found, no fetch.")
else:
    pr_dict = {}  # {pr_number: {title, created_at, author}}

    while True:
        response = requests.get(url, headers=headers, params=params, timeout=60)
        response.raise_for_status()
        prs = response.json()
        if not prs:
            break
        for pr in prs:
            # Only keep merged PRs (comment out to keep all)
            if pr["merged_at"] is None:
                continue

            pr_dict[str(pr["number"])] = {
                "title": pr["title"],
                "created_at": pr["created_at"],
                "author": pr["user"]["login"],
            }
        params["page"] += 1

    with open(PR_JSON_FILE, "w", encoding="utf-8") as f:
        json.dump(pr_dict, f, ensure_ascii=False)

    print(f"Saved {len(pr_dict)} PRs to {PR_JSON_FILE}")
# Out:
# Cache found, no fetch.

# %%
# Quickly clean up PRs (drop bot PRs and so on)
import json
import re

title_patterns = [
    r"(?i)pre[- ]?commit",
    r"(?i)dependabot",
]

author_patterns = [
    r"\[bot\]",
    r"(?i)pre[- ]?commit",
]

title_regexes = [re.compile(p) for p in title_patterns]
author_regexes = [re.compile(p) for p in author_patterns]


def match_any(regexes, text: str) -> bool:
    return any(r.search(text) for r in regexes)


with open(PR_JSON_FILE, encoding="utf-8") as f:
    prs = json.load(f)  # {number: {...}}

filtered = {}
uniq_dropped_titles = set()
uniq_dropped_authors = set()

for num, data in prs.items():
    title = (data.get("title") or "").strip()
    author = (data.get("author") or "").strip()

    if match_any(author_regexes, author):
        if author:
            uniq_dropped_authors.add(author)
        continue

    if match_any(title_regexes, title):
        if title:
            uniq_dropped_titles.add(title)
        continue

    filtered[num] = data

# Save cleaned
with open(PR_JSON_FILE, "w", encoding="utf-8") as f:
    json.dump(filtered, f, indent=2, ensure_ascii=False)

print(f"Kept {len(filtered)} PRs. Saved to {PR_JSON_FILE}")
print(f"Dropped by title: (unique titles: {len(uniq_dropped_titles)})")
for t in sorted(uniq_dropped_titles):
    print("  •", (t[:120] + "…") if len(t) > 120 else t)

print(f"Dropped by author: (unique authors: {len(uniq_dropped_authors)})")
for a in sorted(uniq_dropped_authors):
    print("  •", a)
# Out:
# Kept 2445 PRs. Saved to _prs.json
# Dropped by title: (unique titles: 0)
# Dropped by author: (unique authors: 0)

# %%
# Feed PR titles to the LLM year-by-year and merge JSON results.

import json
from collections import defaultdict
from openai import OpenAI

client = OpenAI()

INSTRUCTIONS = """You are an expert technical summarizer.

You will receive GitHub pull request titles for ONE YEAR.
Identify the 6-10 main technical topics for that year.

For each topic, provide a summary of under 10 words.

Rules:
- Avoid personal names and issue numbers.
- Focus on technical subject matter.
- Do not invent topics; fewer than 6 is acceptable if warranted.

Return ONLY valid JSON in exactly this structure (no extra text, no Markdown):

{
  "year": YYYY,
  "topics": ["summary_1", "summary_2", ...]
}
"""


def get_output_text(resp) -> str:
    # SDK helper: prefer .output_text if present, else fall back
    try:
        return resp.output_text
    except AttributeError:
        return resp.output[0].content[0].text


def summarize_year(year: int, titles: list[str]) -> list[dict]:
    # Build compact per-year payload
    bullets = "\n".join(f"- {t}" for t in titles)
    prompt = f"""{INSTRUCTIONS}

YEAR {year} PR titles:
{bullets}
""".strip()

    resp = client.responses.create(
        model=MODEL,
        input=prompt,
        # max_output_tokens=700,
    )
    raw = get_output_text(resp)
    data = json.loads(raw)  # expect strict JSON due to prompt

    return data["topics"]


# Load PRs
with open(PR_JSON_FILE, encoding="utf-8") as f:
    prs = json.load(f)

# Group titles by year
by_year: dict[int, list[str]] = defaultdict(list)
for _, data in prs.items():
    title = (data.get("title") or "").strip()
    if not title:
        continue
    when = (data.get("merged_at") or data.get("created_at") or "").strip()
    if len(when) < 4:
        continue
    year = int(when[:4])
    by_year[year].append(title)

# Deduplicate per-year
for y in list(by_year.keys()):
    by_year[y] = sorted(set(by_year[y]))

# Call the model year-by-year and merge
merged: dict[str, list[str]] = {}
for year in sorted(by_year):
    print(f"Working on {year=}")
    topics = summarize_year(year, by_year[year])
    print(f"{topics=}\n")
    merged[str(year)] = topics

with open(PR_TOPICS_FILE, "w", encoding="utf-8") as f:
    json.dump(merged, f, ensure_ascii=False, indent=2)
# Out:
# Working on year=2013
# topics=['Abinit and abinitio interface improvements', 'Support for additional simulation tools (GULP, Zeo++, OpenBabel)', 'Bug fixes and code maintenance', 'Enhanced unit handling and serialization', 'Phase diagram and visualization updates', 'Molecule and symmetry matching improvements']
#
# Working on year=2014
# topics=['Defects modeling and bug fixes', 'Serialization and parsing improvements', 'Python 3 compatibility updates', 'Ab initio calculations and workflow tools', 'Valence, ionic radii, and site analysis', 'Surface and interface modeling']
#
# Working on year=2015
# topics=['Defect and solute modeling improvements', 'Parser and input/output format enhancements', 'Bug fixes and stability improvements', 'Gaussian, NWChem, Abinit integration', 'Unit handling and testing updates', 'Py3k compatibility and code modernization']
#
# Working on year=2016
# topics=['Structure analysis and transformation methods', 'Tensor and elasticity functionality updates', 'Chemenv environment analysis improvements', 'VASP input/output and parser enhancements', 'Abinit and LAMMPS I/O support added', 'Bug fixes and code refactoring', 'Substrate analysis and visualization enhancements', 'NMR and Gaussian file parsing improvements']
#
# Working on year=2017
# topics=['Lammps data parsing and structure conversion improvements', 'Order parameter and structure motif analysis enhancements', 'Magnetic structure and SOC calculation module updates', 'Elasticity, phonon, and thermodynamic property calculation tools', 'Bug fixes and unit test coverage expansion', 'Surface, adsorption, and interface analysis tools', 'File parsing, I/O, and format compatibility improvements', 'Charge, oxidation state, and Bader charge analysis tools']
#
# Working on year=2018
# topics=['Graph algorithms for atomic and molecular structures', 'Neighborhood and coordination number determination methods', 'Crystallographic structure parsing and manipulation', 'Electronic structure, DOS, and band structure analysis', 'Defect and interface modeling tools', 'Magnetic structure analysis and properties', 'Bug fixes, refactoring, and performance optimizations']
#
# Working on year=2019
# topics=['VASP, LOBSTER, and DFT input/output enhancements', 'Bug fixes and minor improvements across modules', 'New structural analysis algorithms and optimizations', 'Defect and grain boundary generation and analysis', 'Graph, neighbor, and bonding utilities improvements', 'Trajectory, NMR, molecular and interface support']
#
# Working on year=2020
# topics=['Bug fixes and stability improvements', 'Enhancements to neighbor and connectivity algorithms', 'New classes and data structures', 'Phonon, band structure, and spectroscopy features', 'Parser and IO module updates', 'Compatibility updates for dependency versions', 'Plotting and visualization enhancements', 'Refactoring and code cleanups']
#
# Working on year=2021
# topics=['Input/output parser enhancements for VASP, QChem, QE, Lobster', 'Chemical system and phase diagram module updates', 'OPTIMADE and API compliance improvements', 'Defect corrections, bugfixes, and error handling', 'Performance optimizations for data structures and routines', 'Documentation, type hints, and code modernization']
#
# Working on year=2022
# topics=['Code quality, refactoring, and linting improvements', 'Bug fixes and error handling enhancements', 'New features for structure, molecule, and symmetry analysis', 'Updates for quantum chemistry and electronic structure modules', 'Documentation improvements and citation updates', 'Continuous Integration, Python version, and dependency updates', 'Support for new file formats and IO improvements']
#
# Working on year=2023
# topics=['Input/output enhancements for VASP, Lobster, ASE, Q-Chem, FHI-aims', 'New methods and properties for key core classes', 'Improved and expanded testing infrastructure', 'Deprecation and breaking API changes', 'Type annotations, code formatting, and linting upgrades', 'Documentation and docstring improvements', 'Performance optimizations and bug fixes', 'Compatibility and minimum version bumps']
#
# Working on year=2024
# topics=['Enhanced type annotations and Python version support', 'Input/output improvements for VASP, FHI-aims, LOBSTER, CP2K, JDFTx', 'Expanded structure and electronic/phonon property parsing', 'Continuous integration, dependency, and testing enhancements', 'Refactoring and code quality via ruff, docstrings, formatting', 'New convenience methods and options for materials analysis', 'Deprecated features and API migration for modern standards']
#
# Working on year=2025
# topics=['Symmetry handling and crystallographic utilities enhancements', 'Performance improvements in structure parsing and analysis', 'Periodic table data corrections and updates', 'JDFTx IO and infrastructure upgrades', 'Enhanced file format conversion and compatibility', 'Dependency and continuous integration pipeline updates', 'Bug fixes for structure and molecule utilities', 'JSON handling modernization and default changes']

# %%
# Clean up PR summaries (as summary was done year by year,
# make sure wording and so on is consistent)

import json
from openai import OpenAI

client = OpenAI()

INSTRUCTIONS = """You are an expert technical editor.

You will receive a YEAR and that year's pull-request TOPICS (already summarized).
Your task: normalize wording so style is consistent across years.

Rules:
- Max ~8 topics; fewer is fine.
- Each topic under ~10 words.
- Use consistent terms: VASP, FHI-aims, CP2K, LOBSTER, JDFTx, OPTIMADE, JSON, I/O, CI.
- Avoid personal names and issue numbers.
- Deduplicate/merge overlaps.

Return ONLY valid JSON in this exact structure:
{ "year": YYYY, "topics": ["..."] }
"""


def normalize_year(year: int, topics: list[str]) -> list[str]:
    prompt = f"""{INSTRUCTIONS}

YEAR {year} topics:
{chr(10).join(f"- {t}" for t in topics)}
"""
    resp = client.responses.create(
        model=MODEL,
        input=prompt,
        temperature=0.2,
    )
    # pull text from response
    try:
        raw = resp.output_text
    except AttributeError:
        raw = resp.output[0].content[0].text
    data = json.loads(raw)
    return data["topics"]


with open(PR_TOPICS_FILE, encoding="utf-8") as f:
    per_year = json.load(f)

cleaned = {}
for y, topics in per_year.items():
    cleaned[y] = normalize_year(int(y), topics)

with open(PR_TOPICS_FILE, "w", encoding="utf-8") as f:
    json.dump(cleaned, f, ensure_ascii=False, indent=2)
